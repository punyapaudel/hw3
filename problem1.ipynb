# %% [markdown]
# # Part a

# %% [markdown]
# ## Euler Method

# %%
import math
# Initial conditions
x = 0
y = 0

# Step size (h)
h = 0.1

# How many steps to take
steps = 5

print(f"Start: x = {x}, y = {y}, y_exact = {math.tan(x)}, error = {0}")

# Loop to perform Euler's Method
for i in range(steps):
    # 1. Calculate the slope: f(x, y) = y^2 + 1
    slope = y**2 + 1
    
    # 2. Update y: y_new = y_old + h * slope
    y = y + (h * slope)
    
    # 3. Update x: x_new = x_old + h
    x = x + h

    # 4. Exact solution y_exact = tan (x)
    y_exact = math.tan(x)

    # 5. Error (Difference)
    error = abs(y_exact - y)
    
    print(f"Step {i+1}: x = {round(x, 2)}, y = {y:.5f}, y_exact = {y_exact:.5f}, error = {error:.5f}")
# Out:
# Start: x = 0, y = 0, y_exact = 0.0, error = 0
# Step 1: x = 0.1, y = 0.10000, y_exact = 0.10033, error = 0.00033
# Step 2: x = 0.2, y = 0.20100, y_exact = 0.20271, error = 0.00171
# Step 3: x = 0.3, y = 0.30504, y_exact = 0.30934, error = 0.00430
# Step 4: x = 0.4, y = 0.41435, y_exact = 0.42279, error = 0.00845
# Step 5: x = 0.5, y = 0.53151, y_exact = 0.54630, error = 0.01479

# %% [markdown]
# As $x$ increases, the Euler method (being a first-order method) begins to lag behind the actual curve because it assumes the slope is constant across the entire interval $h$.

# %% [markdown]
# ## Runge-Kutta Method

# %%
import math
# Initial conditions
x = 0
y = 0

# Step size (h)
h = 0.1

# How many steps to take
steps = 5

print(f"Start: x = {x}, y = {y}, y_exact = {math.tan(x)}, error = {0}")

# Loop to perform RK2 (Heun's Method)
for i in range(steps):
    # 1. Calculate k1 (Slope at the start)
    # This is exactly the same as the Euler slope: k1 = f(x, y) = y^2 + 1
    k1 = y**2 + 1
    
    # 2. Predict y at the end of the interval (Euler step)
    # We need this temporary y to find the slope at the end
    y_end_predict = y + h * k1
    
    # 3. Calculate k2 (Slope at the end): 
    # We use the x at the end (x + h) and the predicted y: k2 = f(x+h, y_end_predict)
    k2 = y_end_predict**2 + 1
    
    # 4. Update y: Average of start slope (k1) and end slope (k2)
    y = y + (h / 2) * (k1 + k2)
    
    # 5. Update x: x_new = x_old + h
    x = x + h
    
    # 6. Exact solution y_exact = tan(x)
    y_exact = math.tan(x)
    
    # 7. Error (Difference)
    error = abs(y_exact - y)
    
    print(f"Step {i+1}: x = {round(x, 2)}, y = {y:.5f}, y_exact = {y_exact:.5f}, error = {error:.5f}")
# Out:
# Start: x = 0, y = 0, y_exact = 0.0, error = 0
# Step 1: x = 0.1, y = 0.10050, y_exact = 0.10033, error = 0.00017
# Step 2: x = 0.2, y = 0.20304, y_exact = 0.20271, error = 0.00033
# Step 3: x = 0.3, y = 0.30981, y_exact = 0.30934, error = 0.00048
# Step 4: x = 0.4, y = 0.42341, y_exact = 0.42279, error = 0.00062
# Step 5: x = 0.5, y = 0.54702, y_exact = 0.54630, error = 0.00072

# %% [markdown]
# ## Comparision

# %% [markdown]
# Using the same step size ($h=0.1$) and number of steps ($5$), the Runge-Kutta (RK2) method is significantly more accurate than the Euler method. At $x=0.5$, the Euler method has an error of approximately 0.015, while the RK2 method has an error of only 0.0007, demonstrating the superior convergence of higher-order methods.

# %%
import matplotlib.pyplot as plt
import math

# EULER
x_eplot = [0]       # Start with initial x
y_eplot = [0]       # Start with initial y
y_exact_plot = [0] # Start with initial exact value

xe = 0
ye = 0

# Step size (h)
h = 0.1

# How many steps to take
steps = 15

# Loop to perform Euler's Method
for i in range(steps):
    # 1. Calculate the slope: f(x, y) = y^2 + 1
    slope = ye**2 + 1
    
    # 2. Update y: y_new = y_old + h * slope
    ye = ye + (h * slope)
    
    # 3. Update x: x_new = x_old + h
    xe = xe + h

    # 4. Exact solution y_exact = tan (x)
    y_exact = math.tan(xe)

    # 5. Error (Difference)
    error = abs(y_exact - ye)
    

    # Store the values
    x_eplot.append(xe)
    y_eplot.append(ye)
    y_exact_plot.append(y_exact)

# RK2
x_rplot = [0]
y_rplot = [0]
xr = 0
yr = 0


# Loop to perform RK2 (Heun's Method)
for i in range(steps):
    # 1. Calculate k1 (Slope at the start)
    # This is exactly the same as the Euler slope: k1 = f(x, y) = y^2 + 1
    k1 = yr**2 + 1
    
    # 2. Predict y at the end of the interval (Euler step)
    # We need this temporary y to find the slope at the end
    y_end_predict = yr + h * k1
    
    # 3. Calculate k2 (Slope at the end): 
    # We use the x at the end (x + h) and the predicted y: k2 = f(x+h, y_end_predict)
    k2 = y_end_predict**2 + 1
    
    # 4. Update y: Average of start slope (k1) and end slope (k2)
    yr = yr + (h / 2) * (k1 + k2)
    
    # 5. Update x: x_new = x_old + h
    xr = xr + h
    
    # 6. Exact solution y_exact = tan(x)
    y_exact = math.tan(xr)
    
    # 7. Error (Difference)
    error = abs(y_exact - yr)

    x_rplot.append(xr)
    y_rplot.append(yr)
    
    

plt.plot(x_eplot, y_eplot, 'bo--', label='Euler Method')
plt.plot(x_rplot, y_rplot, 'ko--', label='RK2 Method')
plt.plot(x_eplot, y_exact_plot, 'r-', label='Exact Solution (tan x)')

plt.title("Euler Method, RK2 Method and Exact Solution")
plt.xlabel("x")
plt.ylabel("y")
#plt.ylim(-5, 13)
plt.legend()
plt.grid(True)

# %% [markdown]
# Using the same step size ($h=0.1$), the Runge-Kutta (RK2) method is significantly more accurate than the Euler method.

# %% [markdown]
# # Part b

# %% [markdown]
# ## Euler

# %%
import math
# Initial conditions
x = 0
y = 0

# Step size (h)
h = 0.1

# max value of x
x_max = 3.0

# How many steps to take
steps = int(x_max/h)

print(f"Start: x = {x}, y = {y}, y_exact = {math.tan(x)}, error = {0}, slope = {y**2+1}")

# Loop to perform Euler's Method
for i in range(steps):
    # 1. Calculate the slope: f(x, y) = y^2 + 1
    slope = y**2 + 1
    
    # 2. Update y: y_new = y_old + h * slope
    y = y + (h * slope)
    
    # 3. Update x: x_new = x_old + h
    x = x + h

    # 4. Exact solution y_exact = tan (x)
    y_exact = math.tan(x)

    # 5. Error (Difference)
    error = abs(y_exact - y)
    
    print(f"Step {i+1}: x = {round(x, 2)}, y = {y:.5f}, y_exact = {y_exact:.5f}, error = {error:.5f}, slope = {y**2+1}")
# Out:
# Start: x = 0, y = 0, y_exact = 0.0, error = 0, slope = 1
# Step 1: x = 0.1, y = 0.10000, y_exact = 0.10033, error = 0.00033, slope = 1.01
# Step 2: x = 0.2, y = 0.20100, y_exact = 0.20271, error = 0.00171, slope = 1.040401
# Step 3: x = 0.3, y = 0.30504, y_exact = 0.30934, error = 0.00430, slope = 1.09304946260801
# Step 4: x = 0.4, y = 0.41435, y_exact = 0.42279, error = 0.00845, slope = 1.1716818173608654
# Step 5: x = 0.5, y = 0.53151, y_exact = 0.54630, error = 0.01479, slope = 1.2825063115356714
# Step 6: x = 0.6, y = 0.65976, y_exact = 0.68414, error = 0.02437, slope = 1.435288349841101
# Step 7: x = 0.7, y = 0.80329, y_exact = 0.84229, error = 0.03900, slope = 1.6452791524499677
# Step 8: x = 0.8, y = 0.96782, y_exact = 1.02964, error = 0.06182, slope = 1.936676731939826
# Step 9: x = 0.9, y = 1.16149, y_exact = 1.26016, error = 0.09867, slope = 2.3490550305556415
# Step 10: x = 1.0, y = 1.39639, y_exact = 1.55741, error = 0.16101, slope = 2.9499156045435924
# Step 11: x = 1.1, y = 1.69139, y_exact = 1.96476, error = 0.27337, slope = 3.8607843889458913
# Step 12: x = 1.2, y = 2.07746, y_exact = 2.57215, error = 0.49469, slope = 5.3158557778953535
# Step 13: x = 1.3, y = 2.60905, y_exact = 3.60210, error = 0.99305, slope = 7.8071385773579784
# Step 14: x = 1.4, y = 3.38976, y_exact = 5.79788, error = 2.40812, slope = 12.490494691077515
# Step 15: x = 1.5, y = 4.63881, y_exact = 14.10142, error = 9.46261, slope = 22.51858316929735
# Step 16: x = 1.6, y = 6.89067, y_exact = -34.23253, error = 41.12320, slope = 48.481346920383054
# Step 17: x = 1.7, y = 11.73881, y_exact = -7.69660, error = 19.43541, slope = 138.79955922899507
# Step 18: x = 1.8, y = 25.61876, y_exact = -4.28626, error = 29.90502, slope = 657.3209470181495
# Step 19: x = 1.9, y = 91.35086, y_exact = -2.92710, error = 94.27795, slope = 8345.978950999037
# Step 20: x = 2.0, y = 925.94875, y_exact = -2.18504, error = 928.13379, slope = 857382.0902621783
# Step 21: x = 2.1, y = 86664.15778, y_exact = -1.70985, error = 86665.86762, slope = 7510676244.30786
# Step 22: x = 2.2, y = 751154288.58856, y_exact = -1.37382, error = 751154289.96239, slope = 5.6423276526499136e+17
# Step 23: x = 2.3, y = 56423277277653424.00000, y_exact = -1.11921, error = 56423277277653424.00000, slope = 3.183586218750961e+33
# Step 24: x = 2.4, y = 318358621875096210700211299811328.00000, y_exact = -0.91601, error = 318358621875096210700211299811328.00000, slope = 1.0135221212221049e+65
# Step 25: x = 2.5, y = 10135221212221049699717865941582302406450801918975726374176686080.00000, y_exact = -0.74702, error = 10135221212221049699717865941582302406450801918975726374176686080.00000, slope = 1.0272270902065552e+128
# Step 26: x = 2.6, y = 10272270902065552970794827611486252089956724641476393251154354181448419080508596692694070365266064664930788945286397220513382400.00000, y_exact = -0.60160, error = 10272270902065552970794827611486252089956724641476393251154354181448419080508596692694070365266064664930788945286397220513382400.00000, slope = 1.0551954948542264e+254
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[1], line 34
#      31 # 5. Error (Difference)
#      32 error = abs(y_exact - y)
# ---> 34 print(f"Step {i+1}: x = {round(x, 2)}, y = {y:.5f}, y_exact = {y_exact:.5f}, error = {error:.5f}, slope = {y**2+1}")
#
# OverflowError: (34, 'Result too large')

# %% [markdown]
# ## Runge-Kutta

# %%
import math
# Initial conditions
x = 0
y = 0

# Step size (h)
h = 0.1

# max value of x
x_max = 3.0

# How many steps to take
steps = int(x_max/h)

print(f"Start: x = {x}, y = {y}, y_exact = {math.tan(x)}, error = {0}")

# Loop to perform RK2 (Heun's Method)
for i in range(steps):
    # 1. Calculate k1 (Slope at the start)
    # This is exactly the same as the Euler slope: k1 = f(x, y) = y^2 + 1
    k1 = y**2 + 1
    
    # 2. Predict y at the end of the interval (Euler step)
    # We need this temporary y to find the slope at the end
    y_end_predict = y + h * k1
    
    # 3. Calculate k2 (Slope at the end): 
    # We use the x at the end (x + h) and the predicted y: k2 = f(x+h, y_end_predict)
    k2 = y_end_predict**2 + 1
    
    # 4. Update y: Average of start slope (k1) and end slope (k2)
    y = y + (h / 2) * (k1 + k2)
    
    # 5. Update x: x_new = x_old + h
    x = x + h
    
    # 6. Exact solution y_exact = tan(x)
    y_exact = math.tan(x)
    
    # 7. Error (Difference)
    error = abs(y_exact - y)
    
    print(f"Step {i+1}: x = {round(x, 2)}, y = {y:.5f}, y_exact = {y_exact:.5f}, error = {error:.5f}")
# Out:
# Start: x = 0, y = 0, y_exact = 0.0, error = 0
# Step 1: x = 0.1, y = 0.10050, y_exact = 0.10033, error = 0.00017
# Step 2: x = 0.2, y = 0.20304, y_exact = 0.20271, error = 0.00033
# Step 3: x = 0.3, y = 0.30981, y_exact = 0.30934, error = 0.00048
# Step 4: x = 0.4, y = 0.42341, y_exact = 0.42279, error = 0.00062
# Step 5: x = 0.5, y = 0.54702, y_exact = 0.54630, error = 0.00072
# Step 6: x = 0.6, y = 0.68490, y_exact = 0.68414, error = 0.00076
# Step 7: x = 0.7, y = 0.84295, y_exact = 0.84229, error = 0.00066
# Step 8: x = 0.8, y = 1.02989, y_exact = 1.02964, error = 0.00025
# Step 9: x = 0.9, y = 1.25930, y_exact = 1.26016, error = 0.00086
# Step 10: x = 1.0, y = 1.55379, y_exact = 1.55741, error = 0.00362
# Step 11: x = 1.1, y = 1.95409, y_exact = 1.96476, error = 0.01066
# Step 12: x = 1.2, y = 2.54171, y_exact = 2.57215, error = 0.03044
# Step 13: x = 1.3, y = 3.50519, y_exact = 3.60210, error = 0.09692
# Step 14: x = 1.4, y = 5.38779, y_exact = 5.79788, error = 0.41009
# Step 15: x = 1.5, y = 10.45934, y_exact = 14.10142, error = 3.64208
# Step 16: x = 1.6, y = 39.13980, y_exact = -34.23253, error = 73.37233
# Step 17: x = 1.7, y = 1967.34357, y_exact = -7.69660, error = 1975.04018
# Step 18: x = 1.8, y = 7566693533.22732, y_exact = -4.28626, error = 7566693537.51358
# Step 19: x = 1.9, y = 1639058987324663941047805130955554816.00000, y_exact = -2.92710, error = 1639058987324663941047805130955554816.00000
# Step 20: x = 2.0, y = 3608679713800442182651715194638127888050791121497695373594705956392462151235255248604215966707042641545829807994105151267537768678745423478784.00000, y_exact = -2.18504, error = 3608679713800442182651715194638127888050791121497695373594705956392462151235255248604215966707042641545829807994105151267537768678745423478784.00000
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[66], line 29
#      25 y_end_predict = y + h * k1
#      27 # 3. Calculate k2 (Slope at the end):
#      28 # We use the x at the end (x + h) and the predicted y: k2 = f(x+h, y_end_predict)
# ---> 29 k2 = y_end_predict**2 + 1
#      31 # 4. Update y: Average of start slope (k1) and end slope (k2)
#      32 y = y + (h / 2) * (k1 + k2)
#
# OverflowError: (34, 'Result too large')

# %% [markdown]
# As the value of $x$ gets close to $\pi/2 (\approx 1.57)$, the numerical solution starts to break down.\\
#
# The analytical solution is $y = \tan(x)$. The tangent function has a vertical asymptote at $x = \pi/2$. So, at this point, $y$ goes to infinity.\\
#
# Since $dy/dx = y^2 + 1$, as $y \to \infty$, the slope (derivative) becomes infinitely steep.

# %% [markdown]
# ## Plot

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# EULER
x_eplot = [0]       # Start with initial x
y_eplot = [0]       # Start with initial y
y_exact_plot = [0] # Start with initial exact value

xe = 0
ye = 0

# Step size (h)
h = 0.1

# max value of x
x_max = 1.9

# How many steps to take
steps = int(x_max/h)

# Loop to perform Euler's Method
for i in range(steps):
    # 1. Calculate the slope: f(x, y) = y^2 + 1
    slope = ye**2 + 1
    
    # 2. Update y: y_new = y_old + h * slope
    ye = ye + (h * slope)
    
    # 3. Update x: x_new = x_old + h
    xe = xe + h

    # 4. Exact solution y_exact = tan (x)
    y_exact = math.tan(xe)

    # 5. Error (Difference)
    error = abs(y_exact - ye)
    

    # Store the values
    x_eplot.append(xe)
    y_eplot.append(ye)
    y_exact_plot.append(y_exact)

# RK2
x_rplot = [0]
y_rplot = [0]
xr = 0
yr = 0


# Loop to perform RK2 (Heun's Method)
for i in range(steps):
    # 1. Calculate k1 (Slope at the start)
    # This is exactly the same as the Euler slope: k1 = f(x, y) = y^2 + 1
    k1 = yr**2 + 1
    
    # 2. Predict y at the end of the interval (Euler step)
    # We need this temporary y to find the slope at the end
    y_end_predict = yr + h * k1
    
    # 3. Calculate k2 (Slope at the end): 
    # We use the x at the end (x + h) and the predicted y: k2 = f(x+h, y_end_predict)
    k2 = y_end_predict**2 + 1
    
    # 4. Update y: Average of start slope (k1) and end slope (k2)
    yr = yr + (h / 2) * (k1 + k2)
    
    # 5. Update x: x_new = x_old + h
    xr = xr + h
    
    # 6. Exact solution y_exact = tan(x)
    y_exact = math.tan(xr)
    
    # 7. Error (Difference)
    error = abs(y_exact - yr)

    x_rplot.append(xr)
    y_rplot.append(yr)
    
    

plt.plot(x_eplot, y_eplot, 'bo--', label='Euler Method')
plt.plot(x_rplot, y_rplot, 'ko--', label='RK2 Method')
#plt.plot(x_eplot, y_exact_plot, 'r-', label='Exact Solution (tan x)')

 # --- 3. Exact Solution ---
    # Use many points for a smooth curve
x_exact = np.linspace(0, x_max, 200)
y_exact = np.tan(x_exact)
    
    # Mask values near the asymptote for cleaner plotting 
    # (Removes the vertical line connecting +inf to -inf)
y_exact[np.abs(x_exact - np.pi/2) < 0.05] = np.nan

plt.plot(x_exact, y_exact, 'g', label='Exact Solution (tan x)')
 # Add Asymptote Line
plt.axvline(x=np.pi/2, color='green', linestyle=':', label='Asymptote (x=1.57)')

plt.title("Euler Method, RK2 Method and Exact Solution")
plt.xlabel("x")
plt.ylabel("y")
plt.ylim(-10, 40)
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Part c

# %%
import math
# Initial conditions
x = 0
y = 0

# Step size (h)
h = 0.01

# max value of x
x_max = 3.0

# How many steps to take
steps = int(x_max/h)

print(f"Start: x = {x}, y = {y}, y_exact = {math.tan(x)}, error = {0}, slope = {y**2+1}")

# Loop to perform Euler's Method
for i in range(steps):
    # 1. Calculate the slope: f(x, y) = y^2 + 1
    slope = y**2 + 1
    
    # 2. Update y: y_new = y_old + h * slope
    y = y + (h * slope)
    
    # 3. Update x: x_new = x_old + h
    x = x + h

    # 4. Exact solution y_exact = tan (x)
    y_exact = math.tan(x)

    # 5. Error (Difference)
    error = abs(y_exact - y)
    
    print(f"Step {i+1}: x = {round(x, 4)}, y = {y:.8f}, y_exact = {y_exact:.8f}, error = {error:.8f}, slope = {y**2+1}")
# Out:
# Start: x = 0, y = 0, y_exact = 0.0, error = 0, slope = 1
# Step 1: x = 0.01, y = 0.01000000, y_exact = 0.01000033, error = 0.00000033, slope = 1.0001
# Step 2: x = 0.02, y = 0.02000100, y_exact = 0.02000267, error = 0.00000167, slope = 1.000400040001
# Step 3: x = 0.03, y = 0.03000500, y_exact = 0.03000900, error = 0.00000400, slope = 1.0009003000490047
# Step 4: x = 0.04, y = 0.04001400, y_exact = 0.04002135, error = 0.00000734, slope = 1.0016011204681352
# Step 5: x = 0.05, y = 0.05003001, y_exact = 0.05004171, error = 0.00001169, slope = 1.0025030023613946
# Step 6: x = 0.06, y = 0.06005504, y_exact = 0.06007210, error = 0.00001706, slope = 1.0036066083853665
# Step 7: x = 0.07, y = 0.07009111, y_exact = 0.07011456, error = 0.00002345, slope = 1.0049127638009328
# Step 8: x = 0.08, y = 0.08014024, y_exact = 0.08017110, error = 0.00003087, slope = 1.0064224578029004
# Step 9: x = 0.09, y = 0.09020446, y_exact = 0.09024379, error = 0.00003933, slope = 1.008136845132253
# Step 10: x = 0.1, y = 0.10028583, y_exact = 0.10033467, error = 0.00004884, slope = 1.0100572479755798
# Step 11: x = 0.11, y = 0.11038640, y_exact = 0.11044582, error = 0.00005942, slope = 1.0121851581570913
# Step 12: x = 0.12, y = 0.12050826, y_exact = 0.12057934, error = 0.00007108, slope = 1.0145222396295144
# Step 13: x = 0.13, y = 0.13065348, y_exact = 0.13073732, error = 0.00008384, slope = 1.0170703312710685
# Step 14: x = 0.14, y = 0.14082418, y_exact = 0.14092189, error = 0.00009771, slope = 1.0198314499966645
# Step 15: x = 0.15, y = 0.15102250, y_exact = 0.15113522, error = 0.00011272, slope = 1.0228077941924476
# Step 16: x = 0.16, y = 0.16125057, y_exact = 0.16137946, error = 0.00012889, slope = 1.0260017474838243
# Step 17: x = 0.17, y = 0.17151059, y_exact = 0.17165682, error = 0.00014623, slope = 1.0294158828481763
# Step 18: x = 0.18, y = 0.18180475, y_exact = 0.18196953, error = 0.00016478, slope = 1.0330529670845847
# Step 19: x = 0.19, y = 0.19213528, y_exact = 0.19231984, error = 0.00018456, slope = 1.0369159656540585
# Step 20: x = 0.2, y = 0.20250444, y_exact = 0.20271004, error = 0.00020560, slope = 1.0410080479049975
# Step 21: x = 0.21, y = 0.21291452, y_exact = 0.21314244, error = 0.00022792, slope = 1.045332592699929
# Step 22: x = 0.22, y = 0.22336785, y_exact = 0.22361942, error = 0.00025158, slope = 1.049893194460936
# Step 23: x = 0.23, y = 0.23386678, y_exact = 0.23414336, error = 0.00027658, slope = 1.054693669652659
# Step 24: x = 0.24, y = 0.24441371, y_exact = 0.24471670, error = 0.00030299, slope = 1.0597380637233185
# Step 25: x = 0.25, y = 0.25501109, y_exact = 0.25534192, error = 0.00033083, slope = 1.0650306585258498
# Step 26: x = 0.26, y = 0.26566140, y_exact = 0.26602154, error = 0.00036014, slope = 1.0705759802430215
# Step 27: x = 0.27, y = 0.27636716, y_exact = 0.27675814, error = 0.00039097, slope = 1.0763788078422827
# Step 28: x = 0.28, y = 0.28713095, y_exact = 0.28755433, error = 0.00042338, slope = 1.08244418208811
# Step 29: x = 0.29, y = 0.29795539, y_exact = 0.29841279, error = 0.00045740, slope = 1.0887774151417788
# Step 30: x = 0.3, y = 0.30884317, y_exact = 0.30933625, error = 0.00049308, slope = 1.0953841007807938
# Step 31: x = 0.31, y = 0.31979701, y_exact = 0.32032751, error = 0.00053050, slope = 1.1022701252727096
# Step 32: x = 0.32, y = 0.33081971, y_exact = 0.33138941, error = 0.00056970, slope = 1.1094416789407204
# Step 33: x = 0.33, y = 0.34191412, y_exact = 0.34252487, error = 0.00061074, slope = 1.1169052684612857
# Step 34: x = 0.34, y = 0.35308318, y_exact = 0.35373688, error = 0.00065370, slope = 1.1246677299371355
# Step 35: x = 0.35, y = 0.36432985, y_exact = 0.36502849, error = 0.00069864, slope = 1.13273624279233
# Step 36: x = 0.36, y = 0.37565722, y_exact = 0.37640285, error = 0.00074563, slope = 1.1411183445396462
# Step 37: x = 0.37, y = 0.38706840, y_exact = 0.38786316, error = 0.00079476, slope = 1.1498219464744284
# Step 38: x = 0.38, y = 0.39856662, y_exact = 0.39941272, error = 0.00084610, slope = 1.158855350353241
# Step 39: x = 0.39, y = 0.41015517, y_exact = 0.41105492, error = 0.00089974, slope = 1.1682272661201878
# Step 40: x = 0.4, y = 0.42183745, y_exact = 0.42279322, error = 0.00095577, slope = 1.1779468307486658
# Step 41: x = 0.41, y = 0.43361691, y_exact = 0.43463120, error = 0.00101429, slope = 1.1880236282716408
# Step 42: x = 0.42, y = 0.44549715, y_exact = 0.44657255, error = 0.00107540, slope = 1.1984677110792925
# Step 43: x = 0.43, y = 0.45748183, y_exact = 0.45862102, error = 0.00113920, slope = 1.2092896225691296
# Step 44: x = 0.44, y = 0.46957472, y_exact = 0.47078053, error = 0.00120580, slope = 1.2205004212404686
# Step 45: x = 0.45, y = 0.48177973, y_exact = 0.48305507, error = 0.00127534, slope = 1.232111706332553
# Step 46: x = 0.46, y = 0.49410085, y_exact = 0.49544877, error = 0.00134792, slope = 1.2441356451136234
# Step 47: x = 0.47, y = 0.50654220, y_exact = 0.50796590, error = 0.00142370, slope = 1.2565850019369855
# Step 48: x = 0.48, y = 0.51910805, y_exact = 0.52061084, error = 0.00150279, slope = 1.2694731691896617
# Step 49: x = 0.49, y = 0.53180278, y_exact = 0.53338815, error = 0.00158536, slope = 1.2828142002695895
# Step 50: x = 0.5, y = 0.54463093, y_exact = 0.54630249, error = 0.00167156, slope = 1.2966228447386816
# Step 51: x = 0.51, y = 0.55759715, y_exact = 0.55935872, error = 0.00176156, slope = 1.310914585811438
# Step 52: x = 0.52, y = 0.57070630, y_exact = 0.57256183, error = 0.00185553, slope = 1.3257056803523446
# Step 53: x = 0.53, y = 0.58396336, y_exact = 0.58591701, error = 0.00195366, slope = 1.3410132015701084
# Step 54: x = 0.54, y = 0.59737349, y_exact = 0.59942962, error = 0.00205613, slope = 1.356855084613
# Step 55: x = 0.55, y = 0.61094204, y_exact = 0.61310521, error = 0.00216317, slope = 1.3732501752873494
# Step 56: x = 0.56, y = 0.62467454, y_exact = 0.62694954, error = 0.00227499, slope = 1.3902182821407514
# Step 57: x = 0.57, y = 0.63857672, y_exact = 0.64096855, error = 0.00239183, slope = 1.4077802321729427
# Step 58: x = 0.58, y = 0.65265453, y_exact = 0.65516845, error = 0.00251392, slope = 1.4259579304608438
# Step 59: x = 0.59, y = 0.66691411, y_exact = 0.66955565, error = 0.00264154, slope = 1.4447744240101386
# Step 60: x = 0.6, y = 0.68136185, y_exact = 0.68413681, error = 0.00277496, slope = 1.4642539701742572
# Step 61: x = 0.61, y = 0.69600439, y_exact = 0.69891886, error = 0.00291447, slope = 1.4844221100130195
# Step 62: x = 0.62, y = 0.71084861, y_exact = 0.71390901, error = 0.00306040, slope = 1.5053057469978297
# Step 63: x = 0.63, y = 0.72590167, y_exact = 0.72911473, error = 0.00321306, slope = 1.5269332315085453
# Step 64: x = 0.64, y = 0.74117100, y_exact = 0.74454382, error = 0.00337282, slope = 1.5493344516093948
# Step 65: x = 0.65, y = 0.75666434, y_exact = 0.76020440, error = 0.00354005, slope = 1.5725409306380658
# Step 66: x = 0.66, y = 0.77238975, y_exact = 0.77610491, error = 0.00371516, slope = 1.5965859321938547
# Step 67: x = 0.67, y = 0.78835561, y_exact = 0.79225417, error = 0.00389856, slope = 1.6215045731681512
# Step 68: x = 0.68, y = 0.80457066, y_exact = 0.80866138, error = 0.00409072, slope = 1.6473339455242204
# Step 69: x = 0.69, y = 0.82104400, y_exact = 0.82533611, error = 0.00429211, slope = 1.6741132476040035
# Step 70: x = 0.7, y = 0.83778513, y_exact = 0.84228838, error = 0.00450325, slope = 1.70188392581835
# Step 71: x = 0.71, y = 0.85480397, y_exact = 0.85952867, error = 0.00472469, slope = 1.730689827664719
# Step 72: x = 0.72, y = 0.87211087, y_exact = 0.87706790, error = 0.00495703, slope = 1.760577367114077
# Step 73: x = 0.73, y = 0.88971664, y_exact = 0.89491753, error = 0.00520089, slope = 1.7915957035177374
# Step 74: x = 0.74, y = 0.90763260, y_exact = 0.91308953, error = 0.00545693, slope = 1.8237969353067154
# Step 75: x = 0.75, y = 0.92587057, y_exact = 0.93159646, error = 0.00572589, slope = 1.8572363098924876
# Step 76: x = 0.76, y = 0.94444293, y_exact = 0.95045146, error = 0.00600853, slope = 1.8919724513307217
# Step 77: x = 0.77, y = 0.96336266, y_exact = 0.96966833, error = 0.00630567, slope = 1.9280676074808452
# Step 78: x = 0.78, y = 0.98264333, y_exact = 0.98926154, error = 0.00661820, slope = 1.9655879185866696
# Step 79: x = 0.79, y = 1.00229921, y_exact = 1.00924629, error = 0.00694708, slope = 2.004603709419672
# Step 80: x = 0.8, y = 1.02234525, y_exact = 1.02963856, error = 0.00729331, slope = 2.0451898073702033
# Step 81: x = 0.81, y = 1.04279715, y_exact = 1.05045514, error = 0.00765800, slope = 2.087425889146726
# Step 82: x = 0.82, y = 1.06367141, y_exact = 1.07171372, error = 0.00804232, slope = 2.131396859053613
# Step 83: x = 0.83, y = 1.08498537, y_exact = 1.09343292, error = 0.00844754, slope = 2.1771932621691605
# Step 84: x = 0.84, y = 1.10675731, y_exact = 1.11563235, error = 0.00887504, slope = 2.2249117361432713
# Step 85: x = 0.85, y = 1.12900642, y_exact = 1.13833271, error = 0.00932629, slope = 2.2746555057856277
# Step 86: x = 0.86, y = 1.15175298, y_exact = 1.16155586, error = 0.00980288, slope = 2.326534925128106
# Step 87: x = 0.87, y = 1.17501833, y_exact = 1.18532486, error = 0.01030653, slope = 2.3806680722291196
# Step 88: x = 0.88, y = 1.19882501, y_exact = 1.20966412, error = 0.01083911, slope = 2.437181402653355
# Step 89: x = 0.89, y = 1.22319682, y_exact = 1.23459946, error = 0.01140264, slope = 2.4962104683208484
# Step 90: x = 0.9, y = 1.24815893, y_exact = 1.26015822, error = 0.01199929, slope = 2.557900709289536
# Step 91: x = 0.91, y = 1.27373793, y_exact = 1.28636938, error = 0.01263145, slope = 2.6224083270328817
# Step 92: x = 0.92, y = 1.29996202, y_exact = 1.31326370, error = 0.01330168, slope = 2.689901248919766
# Step 93: x = 0.93, y = 1.32686103, y_exact = 1.34087383, error = 0.01401280, slope = 2.7605601949220007
# Step 94: x = 0.94, y = 1.35446663, y_exact = 1.36923448, error = 0.01476785, slope = 2.8345798590945916
# Step 95: x = 0.95, y = 1.38281243, y_exact = 1.39838259, error = 0.01557016, slope = 2.9121702201296276
# Step 96: x = 0.96, y = 1.41193413, y_exact = 1.42835749, error = 0.01642336, slope = 2.993557997317273
# Step 97: x = 0.97, y = 1.44186971, y_exact = 1.45920113, error = 0.01733141, slope = 3.0789882706055534
# Step 98: x = 0.98, y = 1.47265960, y_exact = 1.49095827, error = 0.01829867, slope = 3.168726286192564
# Step 99: x = 0.99, y = 1.50434686, y_exact = 1.52367674, error = 0.01932988, slope = 3.2630594722802173
# Step 100: x = 1.0, y = 1.53697745, y_exact = 1.55740772, error = 0.02043027, slope = 3.362299693351386
# Step 101: x = 1.01, y = 1.57060045, y_exact = 1.59220602, error = 0.02160557, slope = 3.466785775703149
# Step 102: x = 1.02, y = 1.60526831, y_exact = 1.62813041, error = 0.02286210, slope = 3.5768863420998125
# Step 103: x = 1.03, y = 1.64103717, y_exact = 1.66524399, error = 0.02420682, slope = 3.693002999447937
# Step 104: x = 1.04, y = 1.67796720, y_exact = 1.70361461, error = 0.02564741, slope = 3.8155739305215093
# Step 105: x = 1.05, y = 1.71612294, y_exact = 1.74331531, error = 0.02719237, slope = 3.9450779491972616
# Step 106: x = 1.06, y = 1.75557372, y_exact = 1.78442483, error = 0.02885111, slope = 4.08203908866592
# Step 107: x = 1.07, y = 1.79639411, y_exact = 1.82702820, error = 0.03063408, slope = 4.2270318039932935
# Step 108: x = 1.08, y = 1.83866443, y_exact = 1.87121734, error = 0.03255291, slope = 4.380686884620625
# Step 109: x = 1.09, y = 1.88247130, y_exact = 1.91709182, error = 0.03462052, slope = 4.543698189416751
# Step 110: x = 1.1, y = 1.92790828, y_exact = 1.96475966, error = 0.03685138, slope = 4.7168303373466065
# Step 111: x = 1.11, y = 1.97507658, y_exact = 2.01433821, error = 0.03926163, slope = 4.900927511474933
# Step 112: x = 1.12, y = 2.02408586, y_exact = 2.06595526, error = 0.04186940, slope = 5.096923563848585
# Step 113: x = 1.13, y = 2.07505509, y_exact = 2.11975014, error = 0.04469505, slope = 5.305853645010936
# Step 114: x = 1.14, y = 2.12811363, y_exact = 2.17587513, error = 0.04776150, slope = 5.52886762603109
# Step 115: x = 1.15, y = 2.18340231, y_exact = 2.23449695, error = 0.05109464, slope = 5.7672456349219035
# Step 116: x = 1.16, y = 2.24107476, y_exact = 2.29579854, error = 0.05472378, slope = 6.022416095648466
# Step 117: x = 1.17, y = 2.30129892, y_exact = 2.35998109, error = 0.05868217, slope = 6.295976739757854
# Step 118: x = 1.18, y = 2.36425869, y_exact = 2.42726636, error = 0.06300767, slope = 6.589719162062225
# Step 119: x = 1.19, y = 2.43015588, y_exact = 2.49789939, error = 0.06774350, slope = 6.905657618042892
# Step 120: x = 1.2, y = 2.49921246, y_exact = 2.57215162, error = 0.07293916, slope = 7.246062918553229
# Step 121: x = 1.21, y = 2.57167309, y_exact = 2.65032459, error = 0.07865151, slope = 7.613502475926731
# Step 122: x = 1.22, y = 2.64780811, y_exact = 2.73275420, error = 0.08494609, slope = 8.010887806506837
# Step 123: x = 1.23, y = 2.72791699, y_exact = 2.81981573, error = 0.09189874, slope = 8.441531113477684
# Step 124: x = 1.24, y = 2.81233230, y_exact = 2.91192986, error = 0.09959756, slope = 8.909212981436108
# Step 125: x = 1.25, y = 2.90142443, y_exact = 3.00956967, error = 0.10814524, slope = 9.418263738237343
# Step 126: x = 1.26, y = 2.99560707, y_exact = 3.11326913, error = 0.11766206, slope = 9.973661717882333
# Step 127: x = 1.27, y = 3.09534369, y_exact = 3.22363319, error = 0.12828950, slope = 10.58115254180775
# Step 128: x = 1.28, y = 3.20115521, y_exact = 3.34134998, error = 0.14019477, slope = 11.247394695187975
# Step 129: x = 1.29, y = 3.31362916, y_exact = 3.46720565, error = 0.15357649, slope = 11.980138207065437
# Step 130: x = 1.3, y = 3.43343054, y_exact = 3.60210245, error = 0.16867191, slope = 12.78844528418054
# Step 131: x = 1.31, y = 3.56131499, y_exact = 3.74708098, error = 0.18576598, slope = 13.68296448983194
# Step 132: x = 1.32, y = 3.69814464, y_exact = 3.90334779, error = 0.20520315, slope = 14.676273773683532
# Step 133: x = 1.33, y = 3.84490738, y_exact = 4.07230984, error = 0.22740246, slope = 15.783312738512334
# Step 134: x = 1.34, y = 4.00274050, y_exact = 4.25561789, error = 0.25287739, slope = 17.02193154628156
# Step 135: x = 1.35, y = 4.17295982, y_exact = 4.45522176, error = 0.28226194, slope = 18.413593658937195
# Step 136: x = 1.36, y = 4.35709576, y_exact = 4.67344120, error = 0.31634545, slope = 19.984283431674346
# Step 137: x = 1.37, y = 4.55693859, y_exact = 4.91305807, error = 0.35611948, slope = 21.765689320855618
# Step 138: x = 1.38, y = 4.77459548, y_exact = 5.17743739, error = 0.40284190, slope = 23.796762036473698
# Step 139: x = 1.39, y = 5.01256310, y_exact = 5.47068864, error = 0.45812554, slope = 26.125788875911073
# Step 140: x = 1.4, y = 5.27382099, y_exact = 5.79788372, error = 0.52406272, slope = 28.813187868221274
# Step 141: x = 1.41, y = 5.56195287, y_exact = 6.16535614, error = 0.60340327, slope = 31.935319748937808
# Step 142: x = 1.42, y = 5.88130607, y_exact = 6.58111946, error = 0.69981339, slope = 35.58976108152033
# Step 143: x = 1.43, y = 6.23720368, y_exact = 7.05546377, error = 0.81826009, slope = 39.902709748022446
# Step 144: x = 1.44, y = 6.63623078, y_exact = 7.60182606, error = 0.96559528, slope = 45.03955893433451
# Step 145: x = 1.45, y = 7.08662637, y_exact = 8.23809275, error = 1.15146639, slope = 51.220273265477836
# Step 146: x = 1.46, y = 7.59882910, y_exact = 8.98860760, error = 1.38977850, slope = 58.74220368577978
# Step 147: x = 1.47, y = 8.18625114, y_exact = 9.88737489, error = 1.70112376, slope = 68.01470767007447
# Step 148: x = 1.48, y = 8.86639821, y_exact = 10.98337931, error = 2.11698110, slope = 79.61301727529515
# Step 149: x = 1.49, y = 9.66252839, y_exact = 12.34985644, error = 2.68732806, slope = 94.3644548096288
# Step 150: x = 1.5, y = 10.60617293, y_exact = 14.10141995, error = 3.49524701, slope = 113.49090430726845
# Step 151: x = 1.51, y = 11.74108198, y_exact = 16.42809170, error = 4.68700973, slope = 138.85300599384018
# Step 152: x = 1.52, y = 13.12961204, y_exact = 19.66952782, error = 6.53991578, slope = 173.38671224410288
# Step 153: x = 1.53, y = 14.86347916, y_exact = 24.49841044, error = 9.63493128, slope = 221.9230127253652
# Step 154: x = 1.54, y = 17.08270929, y_exact = 32.46113891, error = 15.37842963, slope = 292.8189565762847
# Step 155: x = 1.55, y = 20.01089885, y_exact = 48.07848248, error = 28.06758363, slope = 401.43607288628476
# Step 156: x = 1.56, y = 24.02525958, y_exact = 92.62049632, error = 68.59523674, slope = 578.2130979534269
# Step 157: x = 1.57, y = 29.80739056, y_exact = 1255.76559150, error = 1225.95820094, slope = 889.4805320517934
# Step 158: x = 1.58, y = 38.70219588, y_exact = -108.64920360, error = 147.35139949, slope = 1498.8599660459324
# Step 159: x = 1.59, y = 53.69079554, y_exact = -52.06696965, error = 105.75776519, slope = 2883.7015259228433
# Step 160: x = 1.6, y = 82.52781080, y_exact = -34.23253274, error = 116.76034354, slope = 6811.83955562798
# Step 161: x = 1.61, y = 150.64620636, y_exact = -25.49474466, error = 176.14095102, slope = 22695.27948988089
# Step 162: x = 1.62, y = 377.59900126, y_exact = -20.30728204, error = 397.90628330, slope = 142582.00574969783
# Step 163: x = 1.63, y = 1803.41905875, y_exact = -16.87110469, error = 1820.29016344, slope = 3252321.3014742862
# Step 164: x = 1.64, y = 34326.63207350, y_exact = -14.42702477, error = 34341.05909826, slope = 1178317670.5091684
# Step 165: x = 1.65, y = 11817503.33716518, y_exact = -12.59926479, error = 11817515.93642997, slope = 139653385123911.14
# Step 166: x = 1.66, y = 1396545668742.44848633, y_exact = -11.18055035, error = 1396545668753.62915039, slope = 1.9503398048832928e+24
# Step 167: x = 1.67, y = 19503398050229471150080.00000000, y_exact = -10.04718230, error = 19503398050229471150080.00000000, slope = 3.803825355056947e+44
# Step 168: x = 1.68, y = 3803825355056947021717605215734371004186624.00000000, y_exact = -9.12077094, error = 3803825355056947021717605215734371004186624.00000000, slope = 1.446908733177411e+85
# Step 169: x = 1.69, y = 144690873317741101923165810725790351180022254885425269132749651213820626695322861568.00000000, y_exact = -8.34923098, error = 144690873317741101923165810725790351180022254885425269132749651213820626695322861568.00000000, slope = 2.0935448821450603e+166
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[85], line 34
#      31 # 5. Error (Difference)
#      32 error = abs(y_exact - y)
# ---> 34 print(f"Step {i+1}: x = {round(x, 4)}, y = {y:.8f}, y_exact = {y_exact:.8f}, error = {error:.8f}, slope = {y**2+1}")
#
# OverflowError: (34, 'Result too large')

# %%
'''
import math
# Initial conditions
x = 0
y = 0

# Step size (h)
h = 0.01

# max value of x
x_max = 3.0

# How many steps to take
steps = int(x_max/h)

print(f"Start: x = {x}, y = {y}, y_exact = {math.tan(x)}, error = {0}, slope = {y**2+1}")

# Loop to perform Euler's Method
for i in range(steps):
    # 1. Calculate the slope: f(x, y) = y^2 + 1
    slope = y**2 + 1
    
    # 2. Update y: y_new = y_old + h * slope
    y = y + (h * slope)
    
    # 3. Update x: x_new = x_old + h
    x = x + h

    # 4. Exact solution y_exact = tan (x)
    y_exact = math.tan(x)

    # 5. Error (Difference)
    error = abs(y_exact - y)
    
    print(f"Step {i+1}: x = {round(x, 4)}, y = {y:.8f}, y_exact = {y_exact:.8f}, error = {error:.8f}, slope = {y**2+1}")
    '''
# Out:
# '\nimport math\n# Initial conditions\nx = 0\ny = 0\n\n# Step size (h)\nh = 0.01\n\n# max value of x\nx_max = 3.0\n\n# How many steps to take\nsteps = int(x_max/h)\n\nprint(f"Start: x = {x}, y = {y}, y_exact = {math.tan(x)}, error = {0}, slope = {y**2+1}")\n\n# Loop to perform Euler\'s Method\nfor i in range(steps):\n    # 1. Calculate the slope: f(x, y) = y^2 + 1\n    slope = y**2 + 1\n    \n    # 2. Update y: y_new = y_old + h * slope\n    y = y + (h * slope)\n    \n    # 3. Update x: x_new = x_old + h\n    x = x + h\n\n    # 4. Exact solution y_exact = tan (x)\n    y_exact = math.tan(x)\n\n    # 5. Error (Difference)\n    error = abs(y_exact - y)\n    \n    print(f"Step {i+1}: x = {round(x, 4)}, y = {y:.8f}, y_exact = {y_exact:.8f}, error = {error:.8f}, slope = {y**2+1}")\n    '

# %% [markdown]
# Lets calculate the error of both methods at the value of $x = 0.5$ with the step size of $h = 0.1$ and $h = 0.01$.

# %%
import math

target_x = 0.5

# The "True" answer at x = 0.5
exact_y = math.tan(target_x)

print(f"Exact Y at x=0.5: {exact_y:.6f}\n")


# PART 1: Check Euler Method

print("Euler Method")

# Test 1: Big Step (h = 0.1)
y = 0
h = 0.1
steps = int(target_x / h) # 5 steps

for i in range(steps):
    slope = y**2 + 1
    y = y + h * slope

error_big = abs(exact_y - y)
print(f"Error with h=0.1:  {error_big:.6f} (y = {y:.6f})")

# Test 2: Small Step (h = 0.01)
y = 0
h = 0.01
steps = int(target_x / h) # 50 steps

for i in range(steps):
    slope = y**2 + 1
    y = y + h * slope

error_small = abs(exact_y - y)
print(f"Error with h=0.01: {error_small:.6f} (y = {y:.6f})")

# Calculate how much better it got
print(f"Improvement: {error_big / error_small:.1f} times better\n")


# PART 2: Check RK2 Method

print("Runge-Kutta (RK2) Method")

# Test 1: Big Step (h = 0.1)
y = 0
h = 0.1
steps = int(target_x / h)

for i in range(steps):
    k1 = y**2 + 1
    y_pred = y + h * k1
    k2 = y_pred**2 + 1
    y = y + (h/2) * (k1 + k2)

error_big = abs(exact_y - y)
print(f"Error with h=0.1:  {error_big:.6f} (y = {y:.6f})")

# Test 2: Small Step (h = 0.01)
y = 0
h = 0.01
steps = int(target_x / h)

for i in range(steps):
    k1 = y**2 + 1
    y_pred = y + h * k1
    k2 = y_pred**2 + 1
    y = y + (h/2) * (k1 + k2)

error_small = abs(exact_y - y)
print(f"Error with h=0.01: {error_small:.8f} (y = {y:.6f})")

# Calculate how much better it got
print(f"Improvement: {error_big / error_small:.1f} times better")
# Out:
# Exact Y at x=0.5: 0.546302
#
# Euler Method
# Error with h=0.1:  0.014789 (y = 0.531513)
# Error with h=0.01: 0.001672 (y = 0.544631)
# Improvement: 8.8 times better
#
# Runge-Kutta (RK2) Method
# Error with h=0.1:  0.000722 (y = 0.547024)
# Error with h=0.01: 0.00000774 (y = 0.546310)
# Improvement: 93.2 times better

# %% [markdown]
# Decreasing the step size increases accuracy for both methods. However, the Runge-Kutta method improves much faster. Decreasing the step size by a factor of 10 reduced the Euler error by a factor of ~10, but it reduced the RK2 error by a factor of ~100.
